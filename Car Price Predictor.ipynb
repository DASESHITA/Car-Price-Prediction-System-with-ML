# %%
import pandas as pd
car = pd.read_csv("/content/quikr_car.csv")
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
car.shape
# Out:
# (892, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
# cleaning the data
# Finding the errors first
car['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %% [markdown]
# ## ERRORS
# Writing down the errors in the data
# - year has many non-year values
# -yearobject to int
# -price has error
# -kms-has kms with integerw
# -kms_driven object to int
# -kms_driven has nan values
# -fuel_type has nan values
# -keep the first 3 words of the name
#
#
#
# #### CLEANING

# %%
backup=car.copy()

# %%
# cleaning one by one
car=car[car['year'].astype(str) .str.isnumeric()]

# %%
car['year']=car['year'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        0 non-null      object
#  1   company     0 non-null      object
#  2   year        0 non-null      int64
#  3   Price       0 non-null      int64
#  4   kms_driven  0 non-null      object
#  5   fuel_type   0 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 0.0+ bytes

# %%
# Excluding ask for price value
#car=car[car['Price']!="Ask For Price"]
car[car['Price'].astype(str) != "Ask For Price"]
# Out:
# Empty DataFrame
# Columns: [name, company, year, Price, kms_driven, fuel_type]
# Index: []

# %%
car.head(50)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        0 non-null      object
#  1   company     0 non-null      object
#  2   year        0 non-null      int64
#  3   Price       0 non-null      int64
#  4   kms_driven  0 non-null      object
#  5   fuel_type   0 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 0.0+ bytes

# %%
#Removing the commas
#car['Price']=car['Price'].str.replace(',','').astype(int)
car['Price'] =car['Price'].astype(str).str.replace(',', '').astype(int)

# %%
car['kms_driven']=car['kms_driven'].astype(str).str.split(' ').str.get(0).str.replace(',','')

# %%
car=car[car['kms_driven'].str.isnumeric()]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        0 non-null      object
#  1   company     0 non-null      object
#  2   year        0 non-null      int64
#  3   Price       0 non-null      int64
#  4   kms_driven  0 non-null      object
#  5   fuel_type   0 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 0.0+ bytes

# %%
car['kms_driven'].astype(int)
#car['kms_driven'] =car['kms_driven'].astype(str).str.replace(',', '').str.extract('(\d+)')[0].astype(int)
# Out:
# Series([], Name: kms_driven, dtype: int64)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        0 non-null      object
#  1   company     0 non-null      object
#  2   year        0 non-null      int64
#  3   Price       0 non-null      int64
#  4   kms_driven  0 non-null      object
#  5   fuel_type   0 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 0.0+ bytes

# %%
# removing nan values
#car=
car[~car['fuel_type'].isna()]
#car[car['fuel_type'].notna()]
# Out:
# Empty DataFrame
# Columns: [name, company, year, Price, kms_driven, fuel_type]
# Index: []

# %%
car['name']=car['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car.reset_index(drop=True)
# Out:
# Empty DataFrame
# Columns: [name, company, year, Price, kms_driven, fuel_type]
# Index: []

# %%
car.describe()
# Out:
#        year  Price  kms_driven
# count   0.0    0.0         0.0
# mean    NaN    NaN         NaN
# std     NaN    NaN         NaN
# min     NaN    NaN         NaN
# 25%     NaN    NaN         NaN
# 50%     NaN    NaN         NaN
# 75%     NaN    NaN         NaN
# max     NaN    NaN         NaN
